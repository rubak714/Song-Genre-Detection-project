# %% [markdown]
# # Project Name: Recognize genre of a song

# %% [markdown]
# ### Data Source: Spotify Web API

# %% [markdown]
# ## Primary goals to fetch data
#
#
# ### Step-1. Setting up Spotify Developer account
# ##### Logging In to Spotify Developer
# ##### Creating a Client ID
# ##### Retrieving Client ID and Client Secret
# ### Step-2. Reviewing Spotify Web API resources
# ### Step-3. Selecting a partcular OAuth Flow
# ### Step-4. Using Spotipy, a Python library for Spotify API¶
# ##### Installing Spotipy
# ##### Importing and Setting Up Spotipy
# ##### Retrieving Data from Spotify Web API
# ##### Loading Data into DataFrame for Exploratory Data Analysis

# %% [markdown]
# Reference:
# https://developer.spotify.com/documentation/web-api/

# %%
# importing necessary libraries
import numpy as np
import pandas as pd

# %% [markdown]
# # Using ''Spotipy''

# %% [markdown]
# Spotipy: a lightweight Python library for Spotify Web API
#
# With Spotipy we get full access to all of the music data provided by the Spotify platform.
#
# SPOTIPY_CLIENT_ID(cid) and SPOTIPY_CLIENT_SECRET(secret) environment variables have to be used in this purpose.

# %% [markdown]
# Reference:
# https://spotipy.readthedocs.io/en/2.19.0/

# %%
pip install spotipy --upgrade
# Out:
# Requirement already satisfied: spotipy in c:\users\rubai\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\rubai\anaconda3\lib\site-packages (from spotipy) (1.26.9)
# Requirement already satisfied: six>=1.15.0 in c:\users\rubai\anaconda3\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: requests>=2.25.0 in c:\users\rubai\anaconda3\lib\site-packages (from spotipy) (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\rubai\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rubai\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rubai\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Authorization

# %% [markdown]
# Reference:
# https://developer.spotify.com/documentation/general/guides/authorization/

# %% [markdown]
# Authorization refers to the process of granting a user or application access permissions to Spotify data and features. Spotify implements the OAuth 2.0 authorization framework.

# %% [markdown]
# Where:
#
# End User corresponds to the Spotify user. The End User grants access to the protected resources (e.g. playlists, personal information, etc.)
#
# My App is the client that requests access to the protected resources (e.g. a mobile or web app).
#
# Server which hosts the protected resources and provides authentication and authorization via OAuth 2.0.
#
# The access to the protected resources is determined by one or several scopes. Scopes enable your application to access specific functionality (e.g. read a playlist, modify your library or just streaming) on behalf of a user. The set of scopes you set during the authorization, determines the access permissions that the user is asked to grant. You can find detailed information about scopes in the scopes guide.
#
# The authorization process requires valid client credentials: a client ID and a client secret. You can follow the App settings guide to learn how to generate them.
#
# Once the authorization is granted, the authorization server issues an access token, which is used to make API calls on behalf the user or application.
#
# The OAuth2 standard defines four grant types (or flows) to request and get an access token. Spotify implements the following ones:
#
# 1. Authorization code + PKCE extension
# 2. Client credentials
# 3. Implicit grant

# %% [markdown]
# ###  Option 2:
# ### Client Credentials is being used in our project

# %% [markdown]
# # Client Credentials Flow:

# %% [markdown]
# The Client Credentials flow is used in server-to-server authentication. Since this flow does not include authorization, only endpoints that do not access user information can be accessed.

# %% [markdown]
# #### Application(Request Access Token)--(client_id+client_secret)-->Spotify Accounts Service(Return Access Token)--access token-->
# #### User Access Token in requests to Web API--->access token--->Spotify Web API(Returned requested data) and
# ####  User Access Token in requests to Web API<---json object<---Spotify Web API(Returned requested data)

# %% [markdown]
# # OAuth flow usage:

# %% [markdown]
# https://developer.spotify.com/documentation/general/guides/authorization/

# %% [markdown]
# OAuth Flow:
# Client credentials is used that does not include user authorization or access token

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# ### App is set by using following link and client_id and secret have been achieved

# %% [markdown]
# Reference:
# https://developer.spotify.com/documentation/general/guides/authorization/app-settings/

# %%
cid = '37f5190916ce4c96850877cca9b1eda6'
secret = '2c8c98f3070c469099f7741f6af31933'

# %% [markdown]
# Reference: https://spotipy.readthedocs.io/en/2.19.0/

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ### Example of collecting real-time Spotify's audio features or data endpoints from track

# %%
a=sp.audio_features(tracks=['1YwoYPfhuZlLDbJUH1cKSi'])

# %%
a
# Out:
# [{'danceability': 0.744,
#   'energy': 0.434,
#   'key': 5,
#   'loudness': -10.807,
#   'mode': 0,
#   'speechiness': 0.0845,
#   'acousticness': 0.583,
#   'instrumentalness': 0.0151,
#   'liveness': 0.0715,
#   'valence': 0.939,
#   'tempo': 173.871,
#   'type': 'audio_features',
#   'id': '1YwoYPfhuZlLDbJUH1cKSi',
#   'uri': 'spotify:track:1YwoYPfhuZlLDbJUH1cKSi',
#   'track_href': 'https://api.spotify.com/v1/tracks/1YwoYPfhuZlLDbJUH1cKSi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1YwoYPfhuZlLDbJUH1cKSi',
#   'duration_ms': 144360,
#   'time_signature': 3}]

# %% [markdown]
# ### Genre list is attained by using following documentaion >> sp.recommendation_genre_seeds()

# %% [markdown]
# Reference: https://spotipy.readthedocs.io/en/2.14.0/

# %% [markdown]
# # Full Genre List

# %%
genre_list = sp.recommendation_genre_seeds()['genres']

# %%
genre_list
# Out:
# ['acoustic',
#  'afrobeat',
#  'alt-rock',
#  'alternative',
#  'ambient',
#  'anime',
#  'black-metal',
#  'bluegrass',
#  'blues',
#  'bossanova',
#  'brazil',
#  'breakbeat',
#  'british',
#  'cantopop',
#  'chicago-house',
#  'children',
#  'chill',
#  'classical',
#  'club',
#  'comedy',
#  'country',
#  'dance',
#  'dancehall',
#  'death-metal',
#  'deep-house',
#  'detroit-techno',
#  'disco',
#  'disney',
#  'drum-and-bass',
#  'dub',
#  'dubstep',
#  'edm',
#  'electro',
#  'electronic',
#  'emo',
#  'folk',
#  'forro',
#  'french',
#  'funk',
#  'garage',
#  'german',
#  'gospel',
#  'goth',
#  'grindcore',
#  'groove',
#  'grunge',
#  'guitar',
#  'happy',
#  'hard-rock',
#  'hardcore',
#  'hardstyle',
#  'heavy-metal',
#  'hip-hop',
#  'holidays',
#  'honky-tonk',
#  'house',
#  'idm',
#  'indian',
#  'indie',
#  'indie-pop',
#  'industrial',
#  'iranian',
#  'j-dance',
#  'j-idol',
#  'j-pop',
#  'j-rock',
#  'jazz',
#  'k-pop',
#  'kids',
#  'latin',
#  'latino',
#  'malay',
#  'mandopop',
#  'metal',
#  'metal-misc',
#  'metalcore',
#  'minimal-techno',
#  'movies',
#  'mpb',
#  'new-age',
#  'new-release',
#  'opera',
#  'pagode',
#  'party',
#  'philippines-opm',
#  'piano',
#  'pop',
#  'pop-film',
#  'post-dubstep',
#  'power-pop',
#  'progressive-house',
#  'psych-rock',
#  'punk',
#  'punk-rock',
#  'r-n-b',
#  'rainy-day',
#  'reggae',
#  'reggaeton',
#  'road-trip',
#  'rock',
#  'rock-n-roll',
#  'rockabilly',
#  'romance',
#  'sad',
#  'salsa',
#  'samba',
#  'sertanejo',
#  'show-tunes',
#  'singer-songwriter',
#  'ska',
#  'sleep',
#  'songwriter',
#  'soul',
#  'soundtracks',
#  'spanish',
#  'study',
#  'summer',
#  'swedish',
#  'synth-pop',
#  'tango',
#  'techno',
#  'trance',
#  'trip-hop',
#  'turkish',
#  'work-out',
#  'world-music']

# %%
len(genre_list)
# Out:
# 126

# %% [markdown]
# ### 126 genres are obtained from Spotify Web API

# %% [markdown]
# Reference: https://spotipy.readthedocs.io/en/2.19.0/#features

# %%
# creating empty lists for extraction of some specific desired features
track_name = []
artist_name = []
album_name = []
genre = []
duration_ms = []
popularity = []
explicit = []
track_id = []
artist_id = []

# %% [markdown]
# #### Note:
# Spotify has set the maximum offset to 1000 which was previously 10,000. The following sp.search() returns a maximum of 50 results per query, which is why a nested for loop is utilized.

# %% [markdown]
# #### limit integer
# The maximum number of items to return. Default: 20. Minimum: 1. Maximum: 50. >= 0 and <= 50
#
# #### offset integer
# The index of the first item to return. Default: 0 (the first item). Default value: 0

# %%
# it will be iterated through each genre
for gen in genre_list:
    
    # as requests are limited to only 50 units, so multiple API requests are needed to get 1000 songs per genre for 126 genres
    for i in range(0,1000,50):
        
        q = 'genre:'+str(gen)
        
        # Storing API request results in a new variable called genre_results
        genre_results = sp.search(q=q, type='track', limit=50,offset=i)
        
        # Iterating through tracks and storing relevant information in lists
        for i, t in enumerate(genre_results['tracks']['items']):
            track_name.append(t['name'])
            artist_name.append(t['artists'][0]['name'])
            album_name.append(t['album']['name'])
            genre.append(gen)
            duration_ms.append(t['duration_ms'])
            popularity.append(t['popularity'])
            explicit.append(t['explicit'])
            track_id.append(t['id'])
            artist_id.append(t['artists'][0]['id'])

# %% [markdown]
# ## Initializing DataFrame 'df' with data

# %%
df = pd.DataFrame({'track_name':track_name,'artist_name':artist_name,
                   'album_name':album_name,'genre':genre,'duration_ms':duration_ms,
                   'popularity':popularity,'explicit':explicit,
                   'track_id' : track_id,'artist_id':artist_id,})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150550 entries, 0 to 150549
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   track_name   150550 non-null  object
#  1   artist_name  150550 non-null  object
#  2   album_name   150550 non-null  object
#  3   genre        150550 non-null  object
#  4   duration_ms  150550 non-null  int64
#  5   popularity   150550 non-null  int64
#  6   explicit     150550 non-null  bool
#  7   track_id     150550 non-null  object
#  8   artist_id    150550 non-null  object
# dtypes: bool(1), int64(2), object(6)
# memory usage: 9.3+ MB

# %% [markdown]
# ## Length of unique genre list

# %%
len(df.genre.unique())
# Out:
# 114

# %% [markdown]
# ## Length of total tracks in unique genre list

# %%
len(df.track_id.unique())
# Out:
# 87028

# %% [markdown]
# ## Shuffling in pandas dataframe without resetting index

# %%
df=df.sample(frac=1)

# %%
df
# Out:
#                                          track_name  \
# 126160                       Yo Perreo Sola - Remix
# 140356                          Sitting In The Park
# 149427                                Hold On To Me
# 128447                     The Train Kept A Rollin'
# 77212                If God / Nothing But the Blood
# ...                                             ...
# 50155   Love Desire - Mike Dunn Blackball Love MixX
# 77993                                          Kiss
# 115328                                  Hug A Hedgy
# 107544                                         愛的魔法
# 34133                             Magic Carpet Ride
#
#                                      artist_name  \
# 126160                                 Bad Bunny
# 140356                             Billy Stewart
# 149427                              Gokhan Akkas
# 128447  Johnny Burnette & The Rock 'N' Roll Trio
# 77212                                    Casey J
# ...                                          ...
# 50155                                  Mike Dunn
# 77993                      London After Midnight
# 115328                               Wonder Pets
# 107544                                        金莎
# 34133                                Steppenwolf
#
#                                        album_name          genre  duration_ms  \
# 126160                     Yo Perreo Sola (Remix)      reggaeton       174027
# 140356                              I Do Love You           soul       194226
# 149427                              Hold On To Me        turkish       171428
# 128447  Johnny Burnette And The Rock 'N Roll Trio    rock-n-roll       139453
# 77212                               The Gathering         gospel       505120
# ...                                           ...            ...          ...
# 50155                           Traxx That Jack U  chicago-house       377419
# 77993                               Psycho Magnet           goth       384733
# 115328                                Wonder Pets          party       165933
# 107544                                       他不愛我       mandopop       191895
# 34133                                  The Second           folk       271573
#
#         popularity  explicit                track_id               artist_id
# 126160          61      True  2cpteAYHcd4cjSxAeCkA52  4q3ewBCX7sLwd24euuV69X
# 140356          52     False  0Iwbts8iqaJJh2kPiXbtgV  21llKqnS025UdaAMslJS4J
# 149427          37     False  6NvaEJ6IhUWTN5XIXSb89o  5eqGxrMJ31RttUaQF9QtUP
# 128447          42     False  7s8spWIA65WP6vG18bXDP1  1neKWNZP74NEuvHZmvMS58
# 77212           42     False  6hre6Y63XrzzTPOBT9NM6e  0B0NzcRnTARbZc83a34cDd
# ...            ...       ...                     ...                     ...
# 50155           16     False  44BjWwxKQM4h4MD2ZC6Yca  55UOywvWbUD9c6C3NSGdft
# 77993           39     False  7clzk3tSYv6VkQWByftu24  51mEqzVhG2n9nD2kBAnWer
# 115328          15     False  3Cii7zTRELKneIXMFUXlkU  7ni4mcsUHE4P5g7Qd15DHD
# 107544          42     False  4X5SAZ4JKejo2tPhvCJhZf  0wK3rMwogVowmeXArZN29T
# 34133           69     False  4c4jJJoaiY21t2TyRZgdWS  1WRM9i067hd2ujxxi8FI3m
#
# [150550 rows x 9 columns]

# %%
df.head()
# Out:
#                             track_name  \
# 126160          Yo Perreo Sola - Remix
# 140356             Sitting In The Park
# 149427                   Hold On To Me
# 128447        The Train Kept A Rollin'
# 77212   If God / Nothing But the Blood
#
#                                      artist_name  \
# 126160                                 Bad Bunny
# 140356                             Billy Stewart
# 149427                              Gokhan Akkas
# 128447  Johnny Burnette & The Rock 'N' Roll Trio
# 77212                                    Casey J
#
#                                        album_name        genre  duration_ms  \
# 126160                     Yo Perreo Sola (Remix)    reggaeton       174027
# 140356                              I Do Love You         soul       194226
# 149427                              Hold On To Me      turkish       171428
# 128447  Johnny Burnette And The Rock 'N Roll Trio  rock-n-roll       139453
# 77212                               The Gathering       gospel       505120
#
#         popularity  explicit                track_id               artist_id
# 126160          61      True  2cpteAYHcd4cjSxAeCkA52  4q3ewBCX7sLwd24euuV69X
# 140356          52     False  0Iwbts8iqaJJh2kPiXbtgV  21llKqnS025UdaAMslJS4J
# 149427          37     False  6NvaEJ6IhUWTN5XIXSb89o  5eqGxrMJ31RttUaQF9QtUP
# 128447          42     False  7s8spWIA65WP6vG18bXDP1  1neKWNZP74NEuvHZmvMS58
# 77212           42     False  6hre6Y63XrzzTPOBT9NM6e  0B0NzcRnTARbZc83a34cDd

# %% [markdown]
# ## Shuffling in pandas dataframe by resetting index

# %%
df=df.sample(frac=1).reset_index(drop=True)

# %%
df.head()
# Out:
#                    track_name                  artist_name  \
# 0            Balanço Zona Sul               Wilson Simonal
# 1   If You Could Read My Mind             Gordon Lightfoot
# 2                  Let Me Out  Future Leaders of the World
# 3  Days to Come (feat. Fiora)                  Seven Lions
# 4                  Summer Jam                 Matt Sassari
#
#                        album_name              genre  duration_ms  popularity  \
# 0                 Tem "Algo Mais"             pagode       152960          38
# 1       If You Could Read My Mind               folk       228840          64
# 2                          LVL IV             grunge       243173          51
# 3                 Days To Come EP  progressive-house       284262          44
# 4  Glasgow Underground Ibiza 2022             french       179000           0
#
#    explicit                track_id               artist_id
# 0     False  73P2hHCGMDlET853vUOq08  6DqFCzjARUV3xH9meu3Bya
# 1     False  57ct8jKi6trntXiRV0NnXi  23rleGXVOVVgTk3xgtmfE4
# 2     False  5Qyywa7BZCkXE5K6O6OHPb  25xjytYjVKPvHiDIgrFodf
# 3     False  1FRFgyPNuqfXIRYlCJ1kwR  6fcTRFpz0yH79qSKfof7lp
# 4     False  32DKwq28DvO0NNE7l6M3KJ  21dVknSLCsK37cWozWDZZS

# %% [markdown]
# # Pulling real-time Spotify's audio features or data endpoints from tracks

# %% [markdown]
# tqdm is a Python library for adding progress bar.
# It helps to configure and display a progress bar with metrics we want to track.

# %%
import tqdm

# %%
from tqdm.notebook import tqdm

# %%
# Pulling audio features
tracks = df.track_id.to_list()
audio_features = []
batchsize = 100

# %%
# Iterating over 100 song batches (due to API limit per request)
for i in tqdm(range(0,len(tracks),batchsize)):
    batch = tracks[i:i+batchsize]
    # Collecting features for 100 tracks
    feature_results = sp.audio_features(batch)
    # Storing individual track info in list
    for track in feature_results:
        if track is not None:
            audio_features.append(track)
# Out:
#   0%|          | 0/1506 [00:00<?, ?it/s]

# %% [markdown]
# ## Accummulated extracted audio features from tracks

# %%
audio_features[0]
# Out:
# {'danceability': 0.511,
#  'energy': 0.321,
#  'key': 5,
#  'loudness': -11.835,
#  'mode': 1,
#  'speechiness': 0.0386,
#  'acousticness': 0.425,
#  'instrumentalness': 0,
#  'liveness': 0.141,
#  'valence': 0.705,
#  'tempo': 139.489,
#  'type': 'audio_features',
#  'id': '73P2hHCGMDlET853vUOq08',
#  'uri': 'spotify:track:73P2hHCGMDlET853vUOq08',
#  'track_href': 'https://api.spotify.com/v1/tracks/73P2hHCGMDlET853vUOq08',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/73P2hHCGMDlET853vUOq08',
#  'duration_ms': 152960,
#  'time_signature': 4}

# %%
af_df = pd.DataFrame.from_dict(data=audio_features,orient='columns')

# %%
af_df
# Out:
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0              0.511  0.3210    5   -11.835     1       0.0386       0.42500
# 1              0.612  0.2400    9   -12.821     1       0.0330       0.74500
# 2              0.553  0.8710    1    -5.310     1       0.0589       0.02460
# 3              0.467  0.7230    0    -7.101     0       0.0536       0.11700
# 4              0.786  0.7980    9    -6.854     0       0.0420       0.03080
# ...              ...     ...  ...       ...   ...          ...           ...
# 150545         0.804  0.6550    0    -8.668     1       0.0435       0.01140
# 150546         0.429  0.8130    8    -6.252     1       0.0661       0.00285
# 150547         0.624  0.8050    9    -2.632     1       0.0290       0.04660
# 150548         0.549  0.9530    5    -6.205     1       0.0587       0.42900
# 150549         0.366  0.0948    9   -20.137     1       0.0396       0.96000
#
#         instrumentalness  liveness  valence    tempo            type  \
# 0               0.000000    0.1410    0.705  139.489  audio_features
# 1               0.000079    0.1150    0.223  122.565  audio_features
# 2               0.000107    0.1810    0.474  144.064  audio_features
# 3               0.000003    0.1860    0.207  139.995  audio_features
# 4               0.013400    0.3670    0.651  130.022  audio_features
# ...                  ...       ...      ...      ...             ...
# 150545          0.316000    0.5850    0.572  119.001  audio_features
# 150546          0.000025    0.0883    0.615  113.283  audio_features
# 150547          0.000000    0.3280    0.770  123.991  audio_features
# 150548          0.000000    0.7110    0.908  170.212  audio_features
# 150549          0.522000    0.2750    0.443  136.202  audio_features
#
#                             id                                   uri  \
# 0       73P2hHCGMDlET853vUOq08  spotify:track:73P2hHCGMDlET853vUOq08
# 1       57ct8jKi6trntXiRV0NnXi  spotify:track:57ct8jKi6trntXiRV0NnXi
# 2       5Qyywa7BZCkXE5K6O6OHPb  spotify:track:5Qyywa7BZCkXE5K6O6OHPb
# 3       1FRFgyPNuqfXIRYlCJ1kwR  spotify:track:1FRFgyPNuqfXIRYlCJ1kwR
# 4       32DKwq28DvO0NNE7l6M3KJ  spotify:track:32DKwq28DvO0NNE7l6M3KJ
# ...                        ...                                   ...
# 150545  47AiGjtI7cOLyPwPSCqTuO  spotify:track:47AiGjtI7cOLyPwPSCqTuO
# 150546  6LhYshEM4feJKQTr7riTBB  spotify:track:6LhYshEM4feJKQTr7riTBB
# 150547  2dRPQFwPqAmc42mDRnsDQu  spotify:track:2dRPQFwPqAmc42mDRnsDQu
# 150548  3OciZ7iaTPVWCw7yKzrMZi  spotify:track:3OciZ7iaTPVWCw7yKzrMZi
# 150549  5wN3m1cgWLuaNqlL1NZxyZ  spotify:track:5wN3m1cgWLuaNqlL1NZxyZ
#
#                                                track_href  \
# 0       https://api.spotify.com/v1/tracks/73P2hHCGMDlE...
# 1       https://api.spotify.com/v1/tracks/57ct8jKi6trn...
# 2       https://api.spotify.com/v1/tracks/5Qyywa7BZCkX...
# 3       https://api.spotify.com/v1/tracks/1FRFgyPNuqfX...
# 4       https://api.spotify.com/v1/tracks/32DKwq28DvO0...
# ...                                                   ...
# 150545  https://api.spotify.com/v1/tracks/47AiGjtI7cOL...
# 150546  https://api.spotify.com/v1/tracks/6LhYshEM4feJ...
# 150547  https://api.spotify.com/v1/tracks/2dRPQFwPqAmc...
# 150548  https://api.spotify.com/v1/tracks/3OciZ7iaTPVW...
# 150549  https://api.spotify.com/v1/tracks/5wN3m1cgWLua...
#
#                                              analysis_url  duration_ms  \
# 0       https://api.spotify.com/v1/audio-analysis/73P2...       152960
# 1       https://api.spotify.com/v1/audio-analysis/57ct...       228840
# 2       https://api.spotify.com/v1/audio-analysis/5Qyy...       243173
# 3       https://api.spotify.com/v1/audio-analysis/1FRF...       284263
# 4       https://api.spotify.com/v1/audio-analysis/32DK...       179000
# ...                                                   ...          ...
# 150545  https://api.spotify.com/v1/audio-analysis/47Ai...       423529
# 150546  https://api.spotify.com/v1/audio-analysis/6LhY...       238627
# 150547  https://api.spotify.com/v1/audio-analysis/2dRP...       212173
# 150548  https://api.spotify.com/v1/audio-analysis/3Oci...       231467
# 150549  https://api.spotify.com/v1/audio-analysis/5wN3...       312933
#
#         time_signature
# 0                    4
# 1                    4
# 2                    4
# 3                    4
# 4                    4
# ...                ...
# 150545               4
# 150546               4
# 150547               4
# 150548               4
# 150549               4
#
# [150550 rows x 18 columns]

# %% [markdown]
# ## matching the audio feature id==track_id

# %%
af_df.rename(columns={'id':'track_id'}, inplace=True)

# %%
af_df
# Out:
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0              0.511  0.3210    5   -11.835     1       0.0386       0.42500
# 1              0.612  0.2400    9   -12.821     1       0.0330       0.74500
# 2              0.553  0.8710    1    -5.310     1       0.0589       0.02460
# 3              0.467  0.7230    0    -7.101     0       0.0536       0.11700
# 4              0.786  0.7980    9    -6.854     0       0.0420       0.03080
# ...              ...     ...  ...       ...   ...          ...           ...
# 150545         0.804  0.6550    0    -8.668     1       0.0435       0.01140
# 150546         0.429  0.8130    8    -6.252     1       0.0661       0.00285
# 150547         0.624  0.8050    9    -2.632     1       0.0290       0.04660
# 150548         0.549  0.9530    5    -6.205     1       0.0587       0.42900
# 150549         0.366  0.0948    9   -20.137     1       0.0396       0.96000
#
#         instrumentalness  liveness  valence    tempo            type  \
# 0               0.000000    0.1410    0.705  139.489  audio_features
# 1               0.000079    0.1150    0.223  122.565  audio_features
# 2               0.000107    0.1810    0.474  144.064  audio_features
# 3               0.000003    0.1860    0.207  139.995  audio_features
# 4               0.013400    0.3670    0.651  130.022  audio_features
# ...                  ...       ...      ...      ...             ...
# 150545          0.316000    0.5850    0.572  119.001  audio_features
# 150546          0.000025    0.0883    0.615  113.283  audio_features
# 150547          0.000000    0.3280    0.770  123.991  audio_features
# 150548          0.000000    0.7110    0.908  170.212  audio_features
# 150549          0.522000    0.2750    0.443  136.202  audio_features
#
#                       track_id                                   uri  \
# 0       73P2hHCGMDlET853vUOq08  spotify:track:73P2hHCGMDlET853vUOq08
# 1       57ct8jKi6trntXiRV0NnXi  spotify:track:57ct8jKi6trntXiRV0NnXi
# 2       5Qyywa7BZCkXE5K6O6OHPb  spotify:track:5Qyywa7BZCkXE5K6O6OHPb
# 3       1FRFgyPNuqfXIRYlCJ1kwR  spotify:track:1FRFgyPNuqfXIRYlCJ1kwR
# 4       32DKwq28DvO0NNE7l6M3KJ  spotify:track:32DKwq28DvO0NNE7l6M3KJ
# ...                        ...                                   ...
# 150545  47AiGjtI7cOLyPwPSCqTuO  spotify:track:47AiGjtI7cOLyPwPSCqTuO
# 150546  6LhYshEM4feJKQTr7riTBB  spotify:track:6LhYshEM4feJKQTr7riTBB
# 150547  2dRPQFwPqAmc42mDRnsDQu  spotify:track:2dRPQFwPqAmc42mDRnsDQu
# 150548  3OciZ7iaTPVWCw7yKzrMZi  spotify:track:3OciZ7iaTPVWCw7yKzrMZi
# 150549  5wN3m1cgWLuaNqlL1NZxyZ  spotify:track:5wN3m1cgWLuaNqlL1NZxyZ
#
#                                                track_href  \
# 0       https://api.spotify.com/v1/tracks/73P2hHCGMDlE...
# 1       https://api.spotify.com/v1/tracks/57ct8jKi6trn...
# 2       https://api.spotify.com/v1/tracks/5Qyywa7BZCkX...
# 3       https://api.spotify.com/v1/tracks/1FRFgyPNuqfX...
# 4       https://api.spotify.com/v1/tracks/32DKwq28DvO0...
# ...                                                   ...
# 150545  https://api.spotify.com/v1/tracks/47AiGjtI7cOL...
# 150546  https://api.spotify.com/v1/tracks/6LhYshEM4feJ...
# 150547  https://api.spotify.com/v1/tracks/2dRPQFwPqAmc...
# 150548  https://api.spotify.com/v1/tracks/3OciZ7iaTPVW...
# 150549  https://api.spotify.com/v1/tracks/5wN3m1cgWLua...
#
#                                              analysis_url  duration_ms  \
# 0       https://api.spotify.com/v1/audio-analysis/73P2...       152960
# 1       https://api.spotify.com/v1/audio-analysis/57ct...       228840
# 2       https://api.spotify.com/v1/audio-analysis/5Qyy...       243173
# 3       https://api.spotify.com/v1/audio-analysis/1FRF...       284263
# 4       https://api.spotify.com/v1/audio-analysis/32DK...       179000
# ...                                                   ...          ...
# 150545  https://api.spotify.com/v1/audio-analysis/47Ai...       423529
# 150546  https://api.spotify.com/v1/audio-analysis/6LhY...       238627
# 150547  https://api.spotify.com/v1/audio-analysis/2dRP...       212173
# 150548  https://api.spotify.com/v1/audio-analysis/3Oci...       231467
# 150549  https://api.spotify.com/v1/audio-analysis/5wN3...       312933
#
#         time_signature
# 0                    4
# 1                    4
# 2                    4
# 3                    4
# 4                    4
# ...                ...
# 150545               4
# 150546               4
# 150547               4
# 150548               4
# 150549               4
#
# [150550 rows x 18 columns]

# %%
final_df = pd.merge(df,af_df,how='inner',on='track_id')

# %%
final_df.shape
# Out:
# (366684, 26)

# %%
final_df.to_csv('extracted_audio_dataset.csv')
